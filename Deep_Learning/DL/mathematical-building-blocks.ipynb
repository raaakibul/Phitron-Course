# %%
# !pip install keras keras-hub --upgrade -q
# Out:
# [notice] A new release of pip is available: 26.0 -> 26.1.1
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic
from IPython import get_ipython

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %%
# %pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\program files\python313\lib\site-packages (from tensorflow) (24.1)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\h\appdata\roaming\python\python313\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\h\appdata\roaming\python\python313\site-packages (from tensorflow) (80.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\program files\python313\lib\site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\h\appdata\roaming\python\python313\site-packages (from tensorflow) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.80.0-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Using cached keras-3.14.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\program files\python313\lib\site-packages (from tensorflow) (2.1.2)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Downloading optree-0.19.1-cp313-cp313-win_amd64.whl.metadata (32 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\h\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\h\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\h\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\h\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\h\appdata\roaming\python\python313\site-packages (from rich->keras>=3.12.0->tensorflow) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl (351.2 MB)
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 0.8/351.2 MB 7.2 MB/s eta 0:00:50
#    ---------------------------------------- 2.1/351.2 MB 6.2 MB/s eta 0:00:57
#     --------------------------------------- 4.7/351.2 MB 9.0 MB/s eta 0:00:39
#     --------------------------------------- 7.3/351.2 MB 9.8 MB/s eta 0:00:36
#    - -------------------------------------- 9.7/351.2 MB 10.0 MB/s eta 0:00:35
#    - -------------------------------------- 11.8/351.2 MB 10.0 MB/s eta 0:00:35
#    - -------------------------------------- 13.9/351.2 MB 10.0 MB/s eta 0:00:34
#    - -------------------------------------- 16.3/351.2 MB 10.0 MB/s eta 0:00:34
#    -- ------------------------------------- 18.4/351.2 MB 10.0 MB/s eta 0:00:34
#    -- ------------------------------------- 20.7/351.2 MB 10.1 MB/s eta 0:00:33
#    -- ------------------------------------- 22.8/351.2 MB 10.1 MB/s eta 0:00:33
#    -- ------------------------------------- 25.2/351.2 MB 10.2 MB/s eta 0:00:33
#    --- ------------------------------------ 27.3/351.2 MB 10.2 MB/s eta 0:00:32
#    --- ------------------------------------ 29.6/351.2 MB 10.3 MB/s eta 0:00:32
#    --- ------------------------------------ 32.0/351.2 MB 10.3 MB/s eta 0:00:31
#    --- ------------------------------------ 34.1/351.2 MB 10.3 MB/s eta 0:00:31
#    ---- ----------------------------------- 35.9/351.2 MB 10.2 MB/s eta 0:00:31
#    ---- ----------------------------------- 37.5/351.2 MB 10.1 MB/s eta 0:00:32
#    ---- ----------------------------------- 39.3/351.2 MB 10.0 MB/s eta 0:00:32
#    ---- ----------------------------------- 41.2/351.2 MB 9.9 MB/s eta 0:00:32
#    ---- ----------------------------------- 43.0/351.2 MB 9.9 MB/s eta 0:00:32
#    ----- ---------------------------------- 44.8/351.2 MB 9.8 MB/s eta 0:00:32
#    ----- ---------------------------------- 46.7/351.2 MB 9.7 MB/s eta 0:00:32
#    ----- ---------------------------------- 48.5/351.2 MB 9.7 MB/s eta 0:00:32
#    ----- ---------------------------------- 50.3/351.2 MB 9.7 MB/s eta 0:00:32
#    ----- ---------------------------------- 52.4/351.2 MB 9.7 MB/s eta 0:00:31
#    ------ --------------------------------- 54.5/351.2 MB 9.6 MB/s eta 0:00:31
#    ------ --------------------------------- 56.4/351.2 MB 9.6 MB/s eta 0:00:31
#    ------ --------------------------------- 58.2/351.2 MB 9.6 MB/s eta 0:00:31
#    ------ --------------------------------- 60.3/351.2 MB 9.6 MB/s eta 0:00:31
#    ------- -------------------------------- 62.4/351.2 MB 9.6 MB/s eta 0:00:31
#    ------- -------------------------------- 64.5/351.2 MB 9.6 MB/s eta 0:00:30
#    ------- -------------------------------- 66.3/351.2 MB 9.6 MB/s eta 0:00:30
MB 3.6 MB/s eta 0:00:05
#    -------------------------------------- - 336.3/351.2 MB 3.7 MB/s eta 0:00:05
#    -------------------------------------- - 337.6/351.2 MB 3.7 MB/s eta 0:00:04
#    -------------------------------------- - 339.0/351.2 MB 3.7 MB/s eta 0:00:04
#    -------------------------------------- - 340.3/351.2 MB 3.7 MB/s eta 0:00:03
#    -------------------------------------- - 341.8/351.2 MB 3.8 MB/s eta 0:00:03
#    ---------------------------------------  343.7/351.2 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------------  345.0/351.2 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------------  346.3/351.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------------  347.3/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  348.1/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  348.9/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  349.7/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  350.5/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  351.0/351.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 351.2/351.2 MB 3.5 MB/s eta 0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.80.0-cp313-cp313-win_amd64.whl (4.9 MB)
#    ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/4.9 MB 4.3 MB/s eta 0:00:01
#    ------------ --------------------------- 1.6/4.9 MB 4.2 MB/s eta 0:00:01
#    ------------------- -------------------- 2.4/4.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------- -------------- 3.1/4.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 3.9/4.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 4.7/4.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.9/4.9 MB 3.5 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 3.4 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.9 MB 3.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 2.6/2.9 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 3.0 MB/s eta 0:00:00
# Using cached keras-3.14.1-py3-none-any.whl (1.6 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl (212 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl (60 kB)
# Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.1-cp313-cp313-win_amd64.whl (343 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, termcolor, protobuf, optree, opt_einsum, ml_dtypes, mdurl, h5py, grpcio, google_pasta, gast, absl-py, markdown-it-py, astunparse, rich, keras, tensorflow
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 keras-3.14.1 libclang-18.1.1 markdown-it-py-4.2.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.1 protobuf-7.34.1 rich-15.0.0 tensorflow-2.21.0 termcolor-3.3.0 wheel-0.47.0 wrapt-2.1.2

# %% [markdown]
# ### A first look at a neural network

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9256 - loss: 0.2637
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9678 - loss: 0.1070
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9792 - loss: 0.0707
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9851 - loss: 0.0499
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9888 - loss: 0.0375

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# array([1.4356707e-06, 3.3404428e-09, 3.7700582e-05, 9.5976451e-05,
#        3.7805331e-10, 2.6504647e-06, 2.1567798e-10, 9.9984920e-01,
#        4.3303457e-06, 8.6972877e-06], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# np.int64(7)

# %%
predictions[0][7]
# Out:
# np.float32(0.9998492)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9794 - loss: 0.0651
# test_acc: 0.9793999791145325

# %% [markdown]
# ### Data representations for neural networks

# %% [markdown]
# #### Scalars (rank-0 tensors)

# %%
import numpy as np
x = np.array(12)
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %% [markdown]
# #### Vectors (rank-1 tensors)

# %%
x = np.array([12, 3, 6, 14, 7])
x
# Out:
# array([12,  3,  6, 14,  7])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# #### Matrices (rank-2 tensors)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36, 2]])
x.ndim
# Out:
# 2

# %% [markdown]
# #### Rank-3 tensors and higher-rank tensors

# %%
x = np.array([[[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]]])
x.ndim
# Out:
# 3

# %% [markdown]
# #### Key attributes

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.ndim
# Out:
# 3

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images.dtype
# Out:
# dtype('uint8')

# %%
import matplotlib.pyplot as plt

digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_labels[4]
# Out:
# np.uint8(9)

# %% [markdown]
# #### Manipulating tensors in NumPy

# %%
my_slice = train_images[10:100]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, :, :]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, 0:28, 0:28]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[:, 14:, 14:]

# %%
my_slice = train_images[:, 7:-7, 7:-7]

# %% [markdown]
# #### The notion of data batches

# %%
batch = train_images[:128]

# %%
batch = train_images[128:256]

# %%
n = 3
batch = train_images[128 * n : 128 * (n + 1)]

# %% [markdown]
# #### Real-world examples of data tensors

# %% [markdown]
# ##### Vector data

# %% [markdown]
# ##### Timeseries data or sequence data

# %% [markdown]
# ##### Image data

# %% [markdown]
# ##### Video data

# %% [markdown]
# ### The gears of neural networks: Tensor operations

# %% [markdown]
# #### Element-wise operations

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()
for _ in range(1000):
    z = x + y
    z = np.maximum(z, 0.0)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 0.02 s

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 2.78 s

# %% [markdown]
# #### Broadcasting

# %%
import numpy as np

X = np.random.random((32, 10))
y = np.random.random((10,))

# %%
y = np.expand_dims(y, axis=0)

# %%
Y = np.tile(y, (32, 1))

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np

x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %% [markdown]
# #### Tensor product

# %%
x = np.random.random((32,))
y = np.random.random((32,))

z = np.matmul(x, y)
z = x @ y

# %%
def naive_vector_product(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    z = 0.0
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_product(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_product(x[i, :], y)
    return z

# %%
def naive_matrix_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_product(row_x, column_y)
    return z

# %% [markdown]
# #### Tensor reshaping

# %%
train_images = train_images.reshape((60000, 28 * 28))

# %%
x = np.array([[0., 1.],
              [2., 3.],
              [4., 5.]])
x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6, 1))
x
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [5.]])

# %%
x = x.reshape((2, 3))
x
# Out:
# array([[0., 1., 2.],
#        [3., 4., 5.]])

# %%
x = np.zeros((300, 20))
x = np.transpose(x)
x.shape
# Out:
# (20, 300)

# %% [markdown]
# #### Geometric interpretation of tensor operations

# %% [markdown]
# #### A geometric interpretation of deep learning

# %% [markdown]
# ### The engine of neural networks: Gradient-based optimization

# %% [markdown]
# #### What's a derivative?

# %% [markdown]
# #### Derivative of a tensor operation: The gradient

# %% [markdown]
# #### Stochastic gradient descent

# %% [markdown]
# #### Chaining derivatives: The Backpropagation algorithm

# %% [markdown]
# ##### The chain rule

# %% [markdown]
# ##### Automatic differentiation with computation graphs

# %% [markdown]
# ### Looking back at our first example

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
model.fit(
    train_images,
    train_labels,
    epochs=5,
    batch_size=128,
)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9247 - loss: 0.2646
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9686 - loss: 0.1081
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9796 - loss: 0.0701
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9852 - loss: 0.0493
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9889 - loss: 0.0372

# %% [markdown]
# #### Reimplementing our first example from scratch

# %% [markdown]
# ##### A simple Dense class

# %%
import keras
from keras import ops

class NaiveDense:
    def __init__(self, input_size, output_size, activation=None):
        self.activation = activation
        self.W = keras.Variable(
            shape=(input_size, output_size), initializer="uniform"
        )
        self.b = keras.Variable(shape=(output_size,), initializer="zeros")

    def __call__(self, inputs):
        x = ops.matmul(inputs, self.W)
        x = x + self.b
        if self.activation is not None:
            x = self.activation(x)
        return x

    @property
    def weights(self):
        return [self.W, self.b]

# %% [markdown]
# ##### A simple Sequential class

# %%
class NaiveSequential:
    def __init__(self, layers):
        self.layers = layers

    def __call__(self, inputs):
        x = inputs
        for layer in self.layers:
            x = layer(x)
        return x

    @property
    def weights(self):
        weights = []
        for layer in self.layers:
            weights += layer.weights
        return weights

# %%
model = NaiveSequential(
    [
        NaiveDense(input_size=28 * 28, output_size=512, activation=ops.relu),
        NaiveDense(input_size=512, output_size=10, activation=ops.softmax),
    ]
)
assert len(model.weights) == 4

# %% [markdown]
# ##### A batch generator

# %%
import math

class BatchGenerator:
    def __init__(self, images, labels, batch_size=128):
        assert len(images) == len(labels)
        self.index = 0
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_batches = math.ceil(len(images) / batch_size)

    def next(self):
        images = self.images[self.index : self.index + self.batch_size]
        labels = self.labels[self.index : self.index + self.batch_size]
        self.index += self.batch_size
        return images, labels

# %% [markdown]
# #### Running one training step

# %% [markdown]
# ##### The weight update step

# %%
learning_rate = 1e-3

def update_weights(gradients, weights):
    for g, w in zip(gradients, weights):
        w.assign(w - g * learning_rate)

# %%
from keras import optimizers

optimizer = optimizers.SGD(learning_rate=1e-3)

def update_weights(gradients, weights):
    optimizer.apply_gradients(zip(gradients, weights))

# %% [markdown]
# ##### Gradient computation

# %%
# %%backend tensorflow
# import tensorflow as tf
#
# x = tf.zeros(shape=())
# with tf.GradientTape() as tape:
#     y = 2 * x + 3
# grad_of_y_wrt_x = tape.gradient(y, x)

# %%
# %%backend tensorflow
# def one_training_step(model, images_batch, labels_batch):
#     with tf.GradientTape() as tape:
#         predictions = model(images_batch)
#         loss = ops.sparse_categorical_crossentropy(labels_batch, predictions)
#         average_loss = ops.mean(loss)
#     gradients = tape.gradient(average_loss, model.weights)
#     update_weights(gradients, model.weights)
#     return average_loss

# %% [markdown]
# #### The full training loop

# %%
# %%backend tensorflow
# def fit(model, images, labels, epochs, batch_size=128):
#     for epoch_counter in range(epochs):
#         print(f"Epoch {epoch_counter}")
#         batch_generator = BatchGenerator(images, labels)
#         for batch_counter in range(batch_generator.num_batches):
#             images_batch, labels_batch = batch_generator.next()
#             loss = one_training_step(model, images_batch, labels_batch)
#             if batch_counter % 100 == 0:
#                 print(f"loss at batch {batch_counter}: {loss:.2f}")

# %%
# %%backend tensorflow
# from keras.datasets import mnist
#
# (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
#
# train_images = train_images.reshape((60000, 28 * 28))
# train_images = train_images.astype("float32") / 255
# test_images = test_images.reshape((10000, 28 * 28))
# test_images = test_images.astype("float32") / 255
#
# fit(model, train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 0
# loss at batch 0: 2.32
# loss at batch 100: 2.27
# loss at batch 200: 2.24
# loss at batch 300: 2.20
# loss at batch 400: 2.16
# Epoch 1
# loss at batch 0: 2.13
# loss at batch 100: 2.11
# loss at batch 200: 2.06
# loss at batch 300: 2.03
# loss at batch 400: 1.99
# Epoch 2
# loss at batch 0: 1.94
# loss at batch 100: 1.95
# loss at batch 200: 1.87
# loss at batch 300: 1.84
# loss at batch 400: 1.81
# Epoch 3
# loss at batch 0: 1.74
# loss at batch 100: 1.77
# loss at batch 200: 1.67
# loss at batch 300: 1.65
# loss at batch 400: 1.62
# Epoch 4
# loss at batch 0: 1.54
# loss at batch 100: 1.59
# loss at batch 200: 1.47
# loss at batch 300: 1.46
# loss at batch 400: 1.45
# Epoch 5
# loss at batch 0: 1.35
# loss at batch 100: 1.41
# loss at batch 200: 1.28
# loss at batch 300: 1.29
# loss at batch 400: 1.30
# Epoch 6
# loss at batch 0: 1.19
# loss at batch 100: 1.26
# loss at batch 200: 1.12
# loss at batch 300: 1.14
# loss at batch 400: 1.17
# Epoch 7
# loss at batch 0: 1.06
# loss at batch 100: 1.13
# loss at batch 200: 0.99
# loss at batch 300: 1.03
# loss at batch 400: 1.06
# Epoch 8
# loss at batch 0: 0.95
# loss at batch 100: 1.02
# loss at batch 200: 0.88
# loss at batch 300: 0.93
# loss at batch 400: 0.98
# Epoch 9
# loss at batch 0: 0.86
# loss at batch 100: 0.93
# loss at batch 200: 0.80
# loss at batch 300: 0.85
# loss at batch 400: 0.91

# %% [markdown]
# #### Evaluating the model

# %%
# %%backend tensorflow
# predictions = model(test_images)
# predicted_labels = ops.argmax(predictions, axis=1)
# matches = predicted_labels == test_labels
# f"accuracy: {ops.mean(matches):.2f}"
# Out:
# 'accuracy: 0.84'
